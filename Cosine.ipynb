# %%
A= (2,4)
B = (5,3)
#Need dot product and the magnitude (length) of the vector.

# %%
from scipy.spatial import distance
#SciPy library used for computing distances between sets of points

# %%
#Cosine Distance
d = distance.cosine(A,B)
print(d)
# Out:
# 0.15633851226789253
